# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.shape
df.head()
df.columns
df.dtypes
# Out:
# age             int64
# sex             int64
# cp              int64
# trestbps       object
# chol           object
# fbs            object
# restecg        object
# thalach        object
# exang          object
# oldpeak       float64
# slope          object
# ca             object
# thal           object
# num             int64
# dtype: object
